# %%
import json
import os
import csv 
import pandas as pd

from eval_v1_1_question import evaluate

# %%
def get_augmented_filename(output_dir, question_set, parts_of_speech=None, frequency_percentile=None):
    assert bool(parts_of_speech) ^ bool(frequency_percentile), "Can only pass one of parts_of_speech and frequency_percentile"
    
    if parts_of_speech:
        filename = output_dir+question_set+"_"+model_type+"_"+"_".join(parts_of_speech)+".json"
    elif frequency_percentile:
        filename = output_dir+question_set+"_"+model_type+"_Percentile_"+str(frequency_percentile)+".json"
    
    return filename


def get_augmented_filename(input_dir, model_name, question_set, parts_of_speech=None, frequency_percentile=None):
    if model_name == 'orig':
        filename = input_dir+question_set+".json"
        return filename

    assert bool(parts_of_speech) ^ bool(frequency_percentile), "Can only pass one of parts_of_speech and frequency_percentile"
    
    if parts_of_speech:
        filename = input_dir+question_set+"_"+model_name+"_"+"_".join(parts_of_speech)+".json"
    elif frequency_percentile:
        filename = input_dir+question_set+"_"+model_name+"_Percentile_"+str(frequency_percentile)+".json"

    return filename


def get_prediction_filename(output_dir, model_name, question_set, qa_model, parts_of_speech=None, frequency_percentile=None):
    if model_name == 'orig':
        filename = output_dir+question_set+"_"+qa_model+".json"
        return filename
    
    assert bool(parts_of_speech) ^ bool(frequency_percentile), "Can only pass one of parts_of_speech and frequency_percentile"
    
    if parts_of_speech:
        filename = output_dir+question_set+"_"+model_name+"_"+"_".join(parts_of_speech)+"_"+qa_model+".json"
    elif frequency_percentile:
        filename = output_dir+question_set+"_"+model_name+"_Percentile_"+str(frequency_percentile)+"_"+qa_model+".json"

    return filename

def strip_filename(filepath):
    filename = filepath.split('/')[-1:][0]
    return filename[:-5]


def get_eval_1_1(qa_json, preds_json):
    
    with open(qa_json) as qa_json_file:
        qa = json.load(qa_json_file)['data']

    with open(preds_json) as preds_json_file:
        preds = json.load(preds_json_file)
    
    eval_results, question_results = evaluate(qa, preds)
    
    return eval_results, question_results

augmented_dir = '/data/distribution_shift/augmented_qa/'
predictions_dir = '/data/distribution_shift/augmented_qa/predictions/'

qa_files = {
    "amazon_reviews_v1_0": '/data/distribution_shift/new_qa/amazon_reviews_v1.0.json',
    "reddit_v1_0": '/data/distribution_shift/new_qa/reddit_v1.0.json',
    "new_wiki_v1.0": '/data/distribution_shift/new_qa/new_wiki_v1.0.json',
    "nyt_v1.0": '/data/distribution_shift/new_qa/nyt_v1.0.json',
}

parts_of_speech_list = [
    ['JJ', 'VB'],
    ['JJ'],
    ['VB', 'RB'],
    ['VB'],
    ['RB'],
    ['RB', 'RBR', 'RBZ'],
    ['VB', 'VBD', 'VBG', 'VBN', 'VBP'],
    ['RB', 'RBR', 'RBZ', 'VB', 'VBD', 'VBG' 'VBN', 'VBP']
]

augmenting_models = [
    'orig',
    'bert',
    'roberta'
]

qa_models = [
    'bert-large-cased-whole-word-masking-finetuned-squad',
    'bert-large-uncased-whole-word-masking-finetuned-squad',
    'distilbert-base-cased-distilled-squad',
    'distilbert-base-uncased-distilled-squad'
]

frequency_percentiles = [
    0.10,
    0.20,
    0.30,
    0.50
]


model_results = [["question_set", 
                  "questions", 
                  "predictions", 
                  "augmentation_model", 
                  "parts_of_speech", 
                  "frequency_percentile", 
                  "augmentation_name", 
                  "question_answering_model", 
                  "exact_match", "f1"
                 ]]

model_question_results = [["question_set", 
                           "questions", 
                           "predictions", 
                           "augmentation_model", 
                           "augmentation_name", 
                           "question_answering_model", 
                           "question_id", 
                           "exact_match", 
                           "f1"]
                         ]

for model_name in augmenting_models:
    for question_set, orig_filename in qa_files.items():
        for qa_model in qa_models:

            if model_name == 'orig':
                qa_filepath = orig_filename
                pred_filepath = get_prediction_filename(predictions_dir, model_name, question_set, qa_model)

                if os.path.exists(qa_filepath) and os.path.exists(pred_filepath):
                    print("Predicting for\n QA: {}\n Pred:{}".format(qa_filepath, pred_filepath))
                
                    model_eval, question_results = get_eval_1_1(qa_filepath, pred_filepath)

                    model_results.append([question_set, 
                                          strip_filename(qa_filepath),
                                          strip_filename(pred_filepath),
                                          model_name,
                                          None,
                                          None,
                                          "Original",
                                          qa_model,
                                          model_eval['exact_match'],
                                          model_eval['f1'],
                                         ])

                    # Add meta data and append
                    for question_result in question_results:
                        model_question_results.append([question_set, 
                                                       strip_filename(qa_filepath),
                                                       strip_filename(pred_filepath),
                                                       model_name, 
                                                       "Original",
                                                       qa_model
                                                      ] + question_result
                                                     )

                else:
                    print("Missing one of the orig files:\n{}\n{}\n\n".format(qa_filepath, pred_filepath))


                continue

            for parts_of_speech in parts_of_speech_list:
                qa_filepath = get_augmented_filename(augmented_dir, model_name, question_set, parts_of_speech=parts_of_speech)

                pred_filepath = get_prediction_filename(predictions_dir, model_name, question_set, qa_model, parts_of_speech=parts_of_speech)

                if os.path.exists(qa_filepath) and os.path.exists(pred_filepath):
                    model_eval, question_results = get_eval_1_1(qa_filepath, pred_filepath)

                    model_results.append([question_set, 
                                          strip_filename(qa_filepath),
                                          strip_filename(pred_filepath),
                                          model_name,
                                          parts_of_speech,
                                          None,
                                          "PoS_"+"_".join(parts_of_speech),
                                          qa_model,
                                          model_eval['exact_match'],
                                          model_eval['f1'],
                                         ])

                    # Add meta data and append
                    for question_result in question_results:
                        model_question_results.append([question_set, 
                                                       strip_filename(qa_filepath),
                                                       strip_filename(pred_filepath),
                                                       model_name,
                                                       "PoS_"+"_".join(parts_of_speech),
                                                       qa_model
                                                      ] + question_result
                                                     )

                else:
                    print("Missing one of the files:\n{}\n{}\n\n".format(qa_filepath, pred_filepath))

            for frequency_percentile in frequency_percentiles:
                qa_filepath = get_augmented_filename(augmented_dir, model_name, question_set, frequency_percentile=frequency_percentile)
                pred_filepath = get_prediction_filename(predictions_dir, model_name, question_set, qa_model, frequency_percentile=frequency_percentile)

                if os.path.exists(qa_filepath) and os.path.exists(pred_filepath):

                    model_eval, question_results = get_eval_1_1(qa_filepath, pred_filepath)

                    model_results.append([question_set, 
                                          strip_filename(qa_filepath),
                                          strip_filename(pred_filepath),
                                          model_name,
                                          None,
                                          frequency_percentile,
                                          "Percentile_"+str(frequency_percentile),
                                          qa_model,
                                          model_eval['exact_match'],
                                          model_eval['f1'],
                                         ])

                    for question_result in question_results:
                        model_question_results.append([question_set, 
                                                       strip_filename(qa_filepath),
                                                       strip_filename(pred_filepath),
                                                       model_name,
                                                       "Percentile_"+str(frequency_percentile),
                                                       qa_model
                                                      ] + question_result
                                                     )                    
                else:
                    print("Missing one of the files:\n{}\n{}\n\n".format(qa_filepath, pred_filepath))
# Out:
# Predicting for
#  QA: /data/distribution_shift/new_qa/amazon_reviews_v1.0.json
#  Pred:/data/distribution_shift/augmented_qa/predictions/amazon_reviews_v1_0_bert-large-cased-whole-word-masking-finetuned-squad.json
# Predicting for
#  QA: /data/distribution_shift/new_qa/amazon_reviews_v1.0.json
#  Pred:/data/distribution_shift/augmented_qa/predictions/amazon_reviews_v1_0_bert-large-uncased-whole-word-masking-finetuned-squad.json
# Predicting for
#  QA: /data/distribution_shift/new_qa/amazon_reviews_v1.0.json
#  Pred:/data/distribution_shift/augmented_qa/predictions/amazon_reviews_v1_0_distilbert-base-cased-distilled-squad.json
# Predicting for
#  QA: /data/distribution_shift/new_qa/amazon_reviews_v1.0.json
#  Pred:/data/distribution_shift/augmented_qa/predictions/amazon_reviews_v1_0_distilbert-base-uncased-distilled-squad.json
# Predicting for
#  QA: /data/distribution_shift/new_qa/reddit_v1.0.json
#  Pred:/data/distribution_shift/augmented_qa/predictions/reddit_v1_0_bert-large-cased-whole-word-masking-finetuned-squad.json
# Predicting for
#  QA: /data/distribution_shift/new_qa/reddit_v1.0.json
#  Pred:/data/distribution_shift/augmented_qa/predictions/reddit_v1_0_bert-large-uncased-whole-word-masking-finetuned-squad.json
# Predicting for
#  QA: /data/distribution_shift/new_qa/reddit_v1.0.json
#  Pred:/data/distribution_shift/augmented_qa/predictions/reddit_v1_0_distilbert-base-cased-distilled-squad.json
# Predicting for
#  QA: /data/distribution_shift/new_qa/reddit_v1.0.json
#  Pred:/data/distribution_shift/augmented_qa/predictions/reddit_v1_0_distilbert-base-uncased-distilled-squad.json
# Predicting for
#  QA: /data/distribution_shift/new_qa/new_wiki_v1.0.json
#  Pred:/data/distribution_shift/augmented_qa/predictions/new_wiki_v1.0_bert-large-cased-whole-word-masking-finetuned-squad.json
# Predicting for
#  QA: /data/distribution_shift/new_qa/new_wiki_v1.0.json
#  Pred:/data/distribution_shift/augmented_qa/predictions/new_wiki_v1.0_bert-large-uncased-whole-word-masking-finetuned-squad.json
# Predicting for
#  QA: /data/distribution_shift/new_qa/new_wiki_v1.0.json
#  Pred:/data/distribution_shift/augmented_qa/predictions/new_wiki_v1.0_distilbert-base-cased-distilled-squad.json
# Predicting for
#  QA: /data/distribution_shift/new_qa/new_wiki_v1.0.json
#  Pred:/data/distribution_shift/augmented_qa/predictions/new_wiki_v1.0_distilbert-base-uncased-distilled-squad.json
# Predicting for
#  QA: /data/distribution_shift/new_qa/nyt_v1.0.json
#  Pred:/data/distribution_shift/augmented_qa/predictions/nyt_v1.0_bert-large-cased-whole-word-masking-finetuned-squad.json
# Predicting for
#  QA: /data/distribution_shift/new_qa/nyt_v1.0.json
#  Pred:/data/distribution_shift/augmented_qa/predictions/nyt_v1.0_bert-large-uncased-whole-word-masking-finetuned-squad.json
# Predicting for
#  QA: /data/distribution_shift/new_qa/nyt_v1.0.json
#  Pred:/data/distribution_shift/augmented_qa/predictions/nyt_v1.0_distilbert-base-cased-distilled-squad.json
# Predicting for
#  QA: /data/distribution_shift/new_qa/nyt_v1.0.json
#  Pred:/data/distribution_shift/augmented_qa/predictions/nyt_v1.0_distilbert-base-uncased-distilled-squad.json
# Unanswered question 5d706342c8e4820a9b66f05a will receive score 0.
# Unanswered question 5d6fb418c8e4820a9b66a7ae will receive score 0.
# Unanswered question 5d706575c8e4820a9b66f08f will receive score 0.
# Unanswered question 5d70055bc8e4820a9b66a8c3 will receive score 0.
# Unanswered question 5d70068bc8e4820a9b66ab9c will receive score 0.
# Unanswered question 5d700715c8e4820a9b66acd4 will receive score 0.
# Unanswered question 5d7004a9c8e4820a9b66a800 will receive score 0.
# Unanswered question 5d700632c8e4820a9b66aac5 will receive score 0.
# Unanswered question 5d700632c8e4820a9b66aac8 will receive score 0.
# Unanswered question 5d7004f2c8e4820a9b66a82f will receive score 0.
# Unanswered question 5d700598c8e4820a9b66a94c will receive score 0.
# Unanswered question 5d7023f3c8e4820a9b66d03d will receive score 0.
# Unanswered question 5d700525c8e4820a9b66a87e will receive score 0.
# Unanswered question 5d7005e5c8e4820a9b66a9ff will receive score 0.
# Unanswered question 5d7005e4c8e4820a9b66a9ed will receive score 0.
# Unanswered question 5d700762c8e4820a9b66ad6a will receive score 0.
# Unanswered question 5d700563c8e4820a9b66a8d7 will receive score 0.
# Unanswered question 5d7005d7c8e4820a9b66a9c6 will receive score 0.
# Unanswered question 5d700566c8e4820a9b66a8f4 will receive score 0.
# Unanswered question 5d70056ec8e4820a9b66a8fe will receive score 0.
# Unanswered question 5d700670c8e4820a9b66ab60 will receive score 0.
# Unanswered question 5d700670c8e4820a9b66ab61 will receive score 0.
# Unanswered question 5d7005b0c8e4820a9b66a967 will receive score 0.
# Unanswered question 5d700866c8e4820a9b66afe8 will receive score 0.
# Unanswered question 5d700866c8e4820a9b66afe9 will receive score 0.
# Unanswered question 5d70073ec8e4820a9b66ad26 will receive score 0.
# Unanswered question 5d7005dbc8e4820a9b66a9d7 will receive score 0.
# Unanswered question 5d7006f3c8e4820a9b66ac63 will receive score 0.
# Unanswered question 5d7006f3c8e4820a9b66ac64 will receive score 0.
# Unanswered question 5d7005e7c8e4820a9b66aa09 will receive score 0.
# Unanswered question 5d7005e7c8e4820a9b66aa0a will receive score 0.
# Unanswered question 5d70073fc8e4820a9b66ad2d will receive score 0.
# Unanswered question 5d70209fc8e4820a9b66cc8b will receive score 0.
# Unanswered question 5d7021b2c8e4820a9b66cdc2 will receive score 0.
# Unanswered question 5d70243cc8e4820a9b66d06f will receive score 0.
# Unanswered question 5d700635c8e4820a9b66aadd will receive score 0.
# Unanswered question 5d700600c8e4820a9b66aa4e will receive score 0.
# Unanswered question 5d700616c8e4820a9b66aa6c will receive score 0.
# Unanswered question 5d7006efc8e4820a9b66ac52 will receive score 0.
# Unanswered question 5d700632c8e4820a9b66aab5 will receive score 0.
# Unanswered question 5d700634c8e4820a9b66aad2 will receive score 0.
# Unanswered question 5d700659c8e4820a9b66ab1c will receive score 0.
# Unanswered question 5d700673c8e4820a9b66ab69 will receive score 0.
# Unanswered question 5d700673c8e4820a9b66ab6b will receive score 0.
# Unanswered question 5d70081bc8e4820a9b66af4e will receive score 0.
# Unanswered question 5d70081bc8e4820a9b66af4f will receive score 0.
# Unanswered question 5d7009a2c8e4820a9b66b2a2 will receive score 0.
# Unanswered question 5d7006a3c8e4820a9b66abe6 will receive score 0.
# Unanswered question 5d70436ec8e4820a9b66e6bb will receive score 0.
# Unanswered question 5d704777c8e4820a9b66e89a will receive score 0.
# Unanswered question 5d700a0fc8e4820a9b66b377 will receive score 0.
# Unanswered question 5d700820c8e4820a9b66af5a will receive score 0.
# Unanswered question 5d700715c8e4820a9b66acce will receive score 0.
# Unanswered question 5d7007b4c8e4820a9b66ae6e will receive score 0.
# Unanswered question 5d700853c8e4820a9b66afd4 will receive score 0.
# Unanswered question 5d700853c8e4820a9b66afd5 will receive score 0.
# Unanswered question 5d700a33c8e4820a9b66b3c0 will receive score 0.
# Unanswered question 5d7008f2c8e4820a9b66b125 will receive score 0.
# Unanswered question 5d700730c8e4820a9b66ad13 will receive score 0.
# Unanswered question 5d700920c8e4820a9b66b199 will receive score 0.
# Unanswered question 5d7009fac8e4820a9b66b32f will receive score 0.
# Unanswered question 5d7009fac8e4820a9b66b331 will receive score 0.
# Unanswered question 5d700748c8e4820a9b66ad38 will receive score 0.
# Unanswered question 5d7011b6c8e4820a9b66be33 will receive score 0.
# Unanswered question 5d700759c8e4820a9b66ad4e will receive score 0.
# Unanswered question 5d700759c8e4820a9b66ad4c will receive score 0.
# Unanswered question 5d701495c8e4820a9b66c0ad will receive score 0.
# Unanswered question 5d701495c8e4820a9b66c0af will receive score 0.
# Unanswered question 5d700766c8e4820a9b66ad7c will receive score 0.
# Unanswered question 5d7007e2c8e4820a9b66aed1 will receive score 0.
# Unanswered question 5d7007e2c8e4820a9b66aed2 will receive score 0.
# Unanswered question 5d7007e2c8e4820a9b66aed3 will receive score 0.
# Unanswered question 5d70087dc8e4820a9b66b00b will receive score 0.
# Unanswered question 5d700796c8e4820a9b66ae1f will receive score 0.
# Unanswered question 5d700796c8e4820a9b66ae21 will receive score 0.
# Unanswered question 5d700cebc8e4820a9b66b852 will receive score 0.
# Unanswered question 5d70109ec8e4820a9b66bd0a will receive score 0.
# Unanswered question 5d7008fcc8e4820a9b66b141 will receive score 0.
# Unanswered question 5d700a4ec8e4820a9b66b3fc will receive score 0.
# Unanswered question 5d7007a0c8e4820a9b66ae46 will receive score 0.
# Unanswered question 5d7007a0c8e4820a9b66ae49 will receive score 0.
# Unanswered question 5d70089ec8e4820a9b66b05f will receive score 0.
# Unanswered question 5d70089ec8e4820a9b66b063 will receive score 0.
# Unanswered question 5d7008b2c8e4820a9b66b090 will receive score 0.
# Unanswered question 5d7007bac8e4820a9b66ae7a will receive score 0.
# Unanswered question 5d7007ebc8e4820a9b66aee2 will receive score 0.
# Unanswered question 5d7007ebc8e4820a9b66aee5 will receive score 0.
# Unanswered question 5d70284dc8e4820a9b66d5f7 will receive score 0.
# Unanswered question 5d702c19c8e4820a9b66d997 will receive score 0.
# Unanswered question 5d7007ecc8e4820a9b66aeef will receive score 0.
# Unanswered question 5d700ab3c8e4820a9b66b4c6 will receive score 0.
# Unanswered question 5d700c65c8e4820a9b66b77f will receive score 0.
# Unanswered question 5d700c65c8e4820a9b66b783 will receive score 0.
# Unanswered question 5d7008adc8e4820a9b66b087 will receive score 0.
# Unanswered question 5d7008adc8e4820a9b66b088 will receive score 0.
# Unanswered question 5d7008adc8e4820a9b66b089 will receive score 0.
# Unanswered question 5d700950c8e4820a9b66b1bf will receive score 0.
# Unanswered question 5d700826c8e4820a9b66af62 will receive score 0.
# Unanswered question 5d700842c8e4820a9b66afbb will receive score 0.
# Unanswered question 5d7009adc8e4820a9b66b2aa will receive score 0.
# Unanswered question 5d700a2ec8e4820a9b66b3b3 will receive score 0.
# Unanswered question 5d700a2ec8e4820a9b66b3b6 will receive score 0.
# Unanswered question 5d700caac8e4820a9b66b804 will receive score 0.
# Unanswered question 5d700caac8e4820a9b66b806 will receive score 0.
# Unanswered question 5d7008bfc8e4820a9b66b0af will receive score 0.
# Unanswered question 5d7008c5c8e4820a9b66b0d6 will receive score 0.
# Unanswered question 5d7008e6c8e4820a9b66b10e will receive score 0.
# Unanswered question 5d700903c8e4820a9b66b149 will receive score 0.
# Unanswered question 5d700a18c8e4820a9b66b393 will receive score 0.
# Unanswered question 5d700913c8e4820a9b66b17c will receive score 0.
# Unanswered question 5d700913c8e4820a9b66b17e will receive score 0.
# Unanswered question 5d700968c8e4820a9b66b20d will receive score 0.
# Unanswered question 5d700968c8e4820a9b66b20f will receive score 0.
# Unanswered question 5d700968c8e4820a9b66b210 will receive score 0.
# Unanswered question 5d70097ac8e4820a9b66b225 will receive score 0.
# Unanswered question 5d700d41c8e4820a9b66b8be will receive score 0.
# Unanswered question 5d700b4ac8e4820a9b66b5f1 will receive score 0.
# Unanswered question 5d700cc7c8e4820a9b66b821 will receive score 0.
# Unanswered question 5d700a4ac8e4820a9b66b3f1 will receive score 0.
# Unanswered question 5d700bb3c8e4820a9b66b693 will receive score 0.
# Unanswered question 5d700a54c8e4820a9b66b40d will receive score 0.
# Unanswered question 5d700c5ac8e4820a9b66b75a will receive score 0.
# Unanswered question 5d700a69c8e4820a9b66b419 will receive score 0.
# Unanswered question 5d700a93c8e4820a9b66b491 will receive score 0.
# Unanswered question 5d700b05c8e4820a9b66b549 will receive score 0.
# Unanswered question 5d700b0ec8e4820a9b66b557 will receive score 0.
# Unanswered question 5d700b0ec8e4820a9b66b55b will receive score 0.
# Unanswered question 5d700b4ac8e4820a9b66b5fc will receive score 0.
# Unanswered question 5d700b4fc8e4820a9b66b609 will receive score 0.
# Unanswered question 5d700f6bc8e4820a9b66bb7b will receive score 0.
# Unanswered question 5d700f6bc8e4820a9b66bb7d will receive score 0.
# Unanswered question 5d700f6bc8e4820a9b66bb7e will receive score 0.
# Unanswered question 5d701018c8e4820a9b66bc30 will receive score 0.
# Unanswered question 5d700d81c8e4820a9b66b924 will receive score 0.
# Unanswered question 5d700c8ac8e4820a9b66b7dd will receive score 0.
# Unanswered question 5d700c6bc8e4820a9b66b7a3 will receive score 0.
# Unanswered question 5d700dccc8e4820a9b66b975 will receive score 0.
# Unanswered question 5d704395c8e4820a9b66e6e0 will receive score 0.
# Unanswered question 5d701545c8e4820a9b66c150 will receive score 0.
# Unanswered question 5d700cfcc8e4820a9b66b88c will receive score 0.
# Unanswered question 5d700fe1c8e4820a9b66bbe6 will receive score 0.
# Unanswered question 5d700d20c8e4820a9b66b8b1 will receive score 0.
# Unanswered question 5d700d20c8e4820a9b66b8b5 will receive score 0.
# Unanswered question 5d70109fc8e4820a9b66bd13 will receive score 0.
# Unanswered question 5d701190c8e4820a9b66be05 will receive score 0.
# Unanswered question 5d701190c8e4820a9b66be04 will receive score 0.
# Unanswered question 5d701190c8e4820a9b66be06 will receive score 0.
# Unanswered question 5d701005c8e4820a9b66bc12 will receive score 0.
# Unanswered question 5d701174c8e4820a9b66bdf5 will receive score 0.
# Unanswered question 5d700d73c8e4820a9b66b90b will receive score 0.
# Unanswered question 5d700d7cc8e4820a9b66b91c will receive score 0.
# Unanswered question 5d700db7c8e4820a9b66b959 will receive score 0.
# Unanswered question 5d702159c8e4820a9b66cd40 will receive score 0.
# Unanswered question 5d701195c8e4820a9b66be10 will receive score 0.
# Unanswered question 5d701195c8e4820a9b66be11 will receive score 0.
# Unanswered question 5d700e1ac8e4820a9b66b9e5 will receive score 0.
# Unanswered question 5d700fcac8e4820a9b66bbda will receive score 0.
# Unanswered question 5d700fcac8e4820a9b66bbdb will receive score 0.
# Unanswered question 5d700ed8c8e4820a9b66bae3 will receive score 0.
# Unanswered question 5d700ed8c8e4820a9b66bae2 will receive score 0.
# Unanswered question 5d70107cc8e4820a9b66bce5 will receive score 0.
# Unanswered question 5d700ec7c8e4820a9b66babd will receive score 0.
# Unanswered question 5d700f41c8e4820a9b66bb3f will receive score 0.
# Unanswered question 5d700f41c8e4820a9b66bb40 will receive score 0.
# Unanswered question 5d700f6bc8e4820a9b66bb86 will receive score 0.
# Unanswered question 5d7010aac8e4820a9b66bd2f will receive score 0.
# Unanswered question 5d7010aac8e4820a9b66bd30 will receive score 0.
# Unanswered question 5d701072c8e4820a9b66bcc7 will receive score 0.
# Unanswered question 5d70112bc8e4820a9b66bdb3 will receive score 0.
# Unanswered question 5d701311c8e4820a9b66bfad will receive score 0.
# Unanswered question 5d704392c8e4820a9b66e6d6 will receive score 0.
# Unanswered question 5d704392c8e4820a9b66e6d7 will receive score 0.
# Unanswered question 5d701073c8e4820a9b66bcd2 will receive score 0.
# Unanswered question 5d7010bdc8e4820a9b66bd4d will receive score 0.
# Unanswered question 5d7010fcc8e4820a9b66bd7b will receive score 0.
# Unanswered question 5d70130ac8e4820a9b66bfa3 will receive score 0.
# Unanswered question 5d7012fcc8e4820a9b66bf8e will receive score 0.
# Unanswered question 5d70142cc8e4820a9b66c081 will receive score 0.
# Unanswered question 5d70142cc8e4820a9b66c082 will receive score 0.
# Unanswered question 5d701303c8e4820a9b66bf97 will receive score 0.
# Unanswered question 5d7014edc8e4820a9b66c0f8 will receive score 0.
# Unanswered question 5d701335c8e4820a9b66bfd1 will receive score 0.
# Unanswered question 5d701335c8e4820a9b66bfd3 will receive score 0.
# Unanswered question 5d7018bdc8e4820a9b66c4e3 will receive score 0.
# Unanswered question 5d70133ac8e4820a9b66bfdb will receive score 0.
# Unanswered question 5d7025f4c8e4820a9b66d23b will receive score 0.
# Unanswered question 5d70136ec8e4820a9b66bfff will receive score 0.
# Unanswered question 5d701668c8e4820a9b66c27a will receive score 0.
# Unanswered question 5d7015bdc8e4820a9b66c1cb will receive score 0.
# Unanswered question 5d7014e4c8e4820a9b66c0ec will receive score 0.
# Unanswered question 5d701841c8e4820a9b66c448 will receive score 0.
# Unanswered question 5d70149cc8e4820a9b66c0c1 will receive score 0.
# Unanswered question 5d701520c8e4820a9b66c113 will receive score 0.
# Unanswered question 5d7015e6c8e4820a9b66c1f3 will receive score 0.
# Unanswered question 5d701541c8e4820a9b66c145 will receive score 0.
# Unanswered question 5d701541c8e4820a9b66c147 will receive score 0.
# Unanswered question 5d701ff5c8e4820a9b66cbb3 will receive score 0.
# Unanswered question 5d70239cc8e4820a9b66cfb8 will receive score 0.
# Unanswered question 5d70155bc8e4820a9b66c17f will receive score 0.
# Unanswered question 5d70155bc8e4820a9b66c182 will receive score 0.
# Unanswered question 5d701825c8e4820a9b66c425 will receive score 0.
# Unanswered question 5d701a6cc8e4820a9b66c625 will receive score 0.
# Unanswered question 5d701ba0c8e4820a9b66c717 will receive score 0.
# Unanswered question 5d70181fc8e4820a9b66c41b will receive score 0.
# Unanswered question 5d7015c6c8e4820a9b66c1de will receive score 0.
# Unanswered question 5d7018dbc8e4820a9b66c4ed will receive score 0.
# Unanswered question 5d701766c8e4820a9b66c35f will receive score 0.
# Unanswered question 5d70187fc8e4820a9b66c49e will receive score 0.
# Unanswered question 5d70186bc8e4820a9b66c486 will receive score 0.
# Unanswered question 5d7016adc8e4820a9b66c2cd will receive score 0.
# Unanswered question 5d7016f5c8e4820a9b66c315 will receive score 0.
# Unanswered question 5d7016f5c8e4820a9b66c319 will receive score 0.
# Unanswered question 5d701780c8e4820a9b66c38d will receive score 0.
# Unanswered question 5d70196ec8e4820a9b66c571 will receive score 0.
# Unanswered question 5d701a9ac8e4820a9b66c62f will receive score 0.
# Unanswered question 5d7018f8c8e4820a9b66c4fe will receive score 0.
# Unanswered question 5d7018f8c8e4820a9b66c500 will receive score 0.
# Unanswered question 5d704668c8e4820a9b66e848 will receive score 0.
# Unanswered question 5d7048dbc8e4820a9b66e910 will receive score 0.
# Unanswered question 5d708f46c8e4820a9b66f56d will receive score 0.
# Unanswered question 5d701892c8e4820a9b66c4af will receive score 0.
# Unanswered question 5d701d56c8e4820a9b66c8e6 will receive score 0.
# Unanswered question 5d7025e9c8e4820a9b66d21c will receive score 0.
# Unanswered question 5d7019fec8e4820a9b66c5eb will receive score 0.
# Unanswered question 5d7019fec8e4820a9b66c5ec will receive score 0.
# Unanswered question 5d701bb1c8e4820a9b66c727 will receive score 0.
# Unanswered question 5d701af7c8e4820a9b66c67e will receive score 0.
# Unanswered question 5d701af7c8e4820a9b66c67f will receive score 0.
# Unanswered question 5d701be8c8e4820a9b66c76a will receive score 0.
# Unanswered question 5d701ebec8e4820a9b66ca55 will receive score 0.
# Unanswered question 5d701ebec8e4820a9b66ca56 will receive score 0.
# Unanswered question 5d702056c8e4820a9b66cc1a will receive score 0.
# Unanswered question 5d701be3c8e4820a9b66c762 will receive score 0.
# Unanswered question 5d701becc8e4820a9b66c774 will receive score 0.
# Unanswered question 5d701d5bc8e4820a9b66c8f0 will receive score 0.
# Unanswered question 5d702fddc8e4820a9b66dc6c will receive score 0.
# Unanswered question 5d701d2ac8e4820a9b66c8b4 will receive score 0.
# Unanswered question 5d701d16c8e4820a9b66c895 will receive score 0.
# Unanswered question 5d701cddc8e4820a9b66c84b will receive score 0.
# Unanswered question 5d701f0ac8e4820a9b66cac0 will receive score 0.
# Unanswered question 5d701ddfc8e4820a9b66c954 will receive score 0.
# Unanswered question 5d702098c8e4820a9b66cc78 will receive score 0.
# Unanswered question 5d701de0c8e4820a9b66c95d will receive score 0.
# Unanswered question 5d701ed6c8e4820a9b66ca6e will receive score 0.
# Unanswered question 5d701f8fc8e4820a9b66cb0c will receive score 0.
# Unanswered question 5d701f8fc8e4820a9b66cb0e will receive score 0.
# Unanswered question 5d701e3fc8e4820a9b66c9aa will receive score 0.
# Unanswered question 5d701e61c8e4820a9b66c9ed will receive score 0.
# Unanswered question 5d702133c8e4820a9b66ccfa will receive score 0.
# Unanswered question 5d702133c8e4820a9b66ccfd will receive score 0.
# Unanswered question 5d7022a2c8e4820a9b66cec2 will receive score 0.
# Unanswered question 5d702082c8e4820a9b66cc4b will receive score 0.
# Unanswered question 5d70230bc8e4820a9b66cf2c will receive score 0.
# Unanswered question 5d7023c0c8e4820a9b66cff9 will receive score 0.
# Unanswered question 5d702157c8e4820a9b66cd33 will receive score 0.
# Unanswered question 5d702157c8e4820a9b66cd34 will receive score 0.
# Unanswered question 5d702157c8e4820a9b66cd35 will receive score 0.
# Unanswered question 5d702157c8e4820a9b66cd36 will receive score 0.
# Unanswered question 5d702327c8e4820a9b66cf61 will receive score 0.
# Unanswered question 5d702552c8e4820a9b66d1b8 will receive score 0.
# Unanswered question 5d70209bc8e4820a9b66cc81 will receive score 0.
# Unanswered question 5d70204dc8e4820a9b66cc13 will receive score 0.
# Unanswered question 5d702072c8e4820a9b66cc42 will receive score 0.
# Unanswered question 5d702095c8e4820a9b66cc70 will receive score 0.
# Unanswered question 5d7021eac8e4820a9b66cdf9 will receive score 0.
# Unanswered question 5d702337c8e4820a9b66cf7d will receive score 0.
# Unanswered question 5d702185c8e4820a9b66cd7a will receive score 0.
# Unanswered question 5d7021a3c8e4820a9b66cd99 will receive score 0.
# Unanswered question 5d702245c8e4820a9b66ce4c will receive score 0.
# Unanswered question 5d7028afc8e4820a9b66d64b will receive score 0.
# Unanswered question 5d702588c8e4820a9b66d1df will receive score 0.
# Unanswered question 5d702435c8e4820a9b66d066 will receive score 0.
# Unanswered question 5d7025ecc8e4820a9b66d229 will receive score 0.
# Unanswered question 5d7023dec8e4820a9b66d023 will receive score 0.
# Unanswered question 5d70242bc8e4820a9b66d05d will receive score 0.
# Unanswered question 5d702440c8e4820a9b66d077 will receive score 0.
# Unanswered question 5d70290fc8e4820a9b66d6e1 will receive score 0.
# Unanswered question 5d702a09c8e4820a9b66d781 will receive score 0.
# Unanswered question 5d702a09c8e4820a9b66d783 will receive score 0.
# Unanswered question 5d702a09c8e4820a9b66d784 will receive score 0.
# Unanswered question 5d702669c8e4820a9b66d2a7 will receive score 0.
# Unanswered question 5d702669c8e4820a9b66d2a8 will receive score 0.
# Unanswered question 5d702498c8e4820a9b66d0c5 will receive score 0.
# Unanswered question 5d7024f2c8e4820a9b66d176 will receive score 0.
# Unanswered question 5d7024ffc8e4820a9b66d189 will receive score 0.
# Unanswered question 5d7025d0c8e4820a9b66d207 will receive score 0.
# Unanswered question 5d7025d0c8e4820a9b66d209 will receive score 0.
# Unanswered question 5d7025d0c8e4820a9b66d208 will receive score 0.
# Unanswered question 5d7027a5c8e4820a9b66d56e will receive score 0.
# Unanswered question 5d7027a5c8e4820a9b66d570 will receive score 0.
# Unanswered question 5d702653c8e4820a9b66d289 will receive score 0.
# Unanswered question 5d7028bac8e4820a9b66d673 will receive score 0.
# Unanswered question 5d702785c8e4820a9b66d553 will receive score 0.
# Unanswered question 5d702732c8e4820a9b66d4f9 will receive score 0.
# Unanswered question 5d7028ccc8e4820a9b66d67d will receive score 0.
# Unanswered question 5d7028ccc8e4820a9b66d67e will receive score 0.
# Unanswered question 5d7028ccc8e4820a9b66d680 will receive score 0.
# Unanswered question 5d7028ccc8e4820a9b66d681 will receive score 0.
# Unanswered question 5d7026c8c8e4820a9b66d337 will receive score 0.
# Unanswered question 5d7026d1c8e4820a9b66d349 will receive score 0.
# Unanswered question 5d7026d1c8e4820a9b66d34a will receive score 0.
# Unanswered question 5d7026d7c8e4820a9b66d352 will receive score 0.
# Unanswered question 5d7026dac8e4820a9b66d35c will receive score 0.
# Unanswered question 5d7026dbc8e4820a9b66d370 will receive score 0.
# Unanswered question 5d7026dfc8e4820a9b66d37a will receive score 0.
# Unanswered question 5d7026e0c8e4820a9b66d384 will receive score 0.
# Unanswered question 5d7026e0c8e4820a9b66d38e will receive score 0.
# Unanswered question 5d7026e0c8e4820a9b66d393 will receive score 0.
# Unanswered question 5d70280ac8e4820a9b66d5b5 will receive score 0.
# Unanswered question 5d702725c8e4820a9b66d4ef will receive score 0.
# Unanswered question 5d702725c8e4820a9b66d4f1 will receive score 0.
# Unanswered question 5d702784c8e4820a9b66d54c will receive score 0.
# Unanswered question 5d702919c8e4820a9b66d6ea will receive score 0.
# Unanswered question 5d7028a9c8e4820a9b66d641 will receive score 0.
# Unanswered question 5d7028b2c8e4820a9b66d65f will receive score 0.
# Unanswered question 5d7029bbc8e4820a9b66d767 will receive score 0.
# Unanswered question 5d70290cc8e4820a9b66d6d9 will receive score 0.
# Unanswered question 5d7029b4c8e4820a9b66d761 will receive score 0.
# Unanswered question 5d702c0ac8e4820a9b66d984 will receive score 0.
# Unanswered question 5d702d0fc8e4820a9b66da92 will receive score 0.
# Unanswered question 5d702d0fc8e4820a9b66da93 will receive score 0.
# Unanswered question 5d702a95c8e4820a9b66d82f will receive score 0.
# Unanswered question 5d702b18c8e4820a9b66d890 will receive score 0.
# Unanswered question 5d702acec8e4820a9b66d854 will receive score 0.
# Unanswered question 5d702acec8e4820a9b66d855 will receive score 0.
# Unanswered question 5d702b75c8e4820a9b66d905 will receive score 0.
# Unanswered question 5d702c21c8e4820a9b66d99d will receive score 0.
# Unanswered question 5d702c21c8e4820a9b66d9a0 will receive score 0.
# Unanswered question 5d702cf2c8e4820a9b66da7d will receive score 0.
# Unanswered question 5d702cf2c8e4820a9b66da7f will receive score 0.
# Unanswered question 5d702d18c8e4820a9b66daa7 will receive score 0.
# Unanswered question 5d702cd9c8e4820a9b66da59 will receive score 0.
# Unanswered question 5d702dd6c8e4820a9b66db35 will receive score 0.
# Unanswered question 5d702dd6c8e4820a9b66db37 will receive score 0.
# Unanswered question 5d702ed1c8e4820a9b66dc02 will receive score 0.
# Unanswered question 5d702e78c8e4820a9b66dbbd will receive score 0.
# Unanswered question 5d703188c8e4820a9b66dd53 will receive score 0.
# Unanswered question 5d703188c8e4820a9b66dd56 will receive score 0.
# Unanswered question 5d702ed3c8e4820a9b66dc0b will receive score 0.
# Unanswered question 5d703091c8e4820a9b66dcc3 will receive score 0.
# Unanswered question 5d702ee3c8e4820a9b66dc17 will receive score 0.
# Unanswered question 5d702f4fc8e4820a9b66dc29 will receive score 0.
# Unanswered question 5d7030a4c8e4820a9b66dcd4 will receive score 0.
# Unanswered question 5d7030a4c8e4820a9b66dcd5 will receive score 0.
# Unanswered question 5d7030a4c8e4820a9b66dcd7 will receive score 0.
# Unanswered question 5d702ff0c8e4820a9b66dc89 will receive score 0.
# Unanswered question 5d70315fc8e4820a9b66dd38 will receive score 0.
# Unanswered question 5d7031ddc8e4820a9b66dd84 will receive score 0.
# Unanswered question 5d703059c8e4820a9b66dca3 will receive score 0.
# Unanswered question 5d7031ffc8e4820a9b66dd9c will receive score 0.
# Unanswered question 5d7032b7c8e4820a9b66ddf4 will receive score 0.
# Unanswered question 5d703555c8e4820a9b66df72 will receive score 0.
# Unanswered question 5d703f54c8e4820a9b66e469 will receive score 0.
# Unanswered question 5d7031cbc8e4820a9b66dd71 will receive score 0.
# Unanswered question 5d70344dc8e4820a9b66deee will receive score 0.
# Unanswered question 5d703209c8e4820a9b66dda9 will receive score 0.
# Unanswered question 5d703284c8e4820a9b66ddd5 will receive score 0.
# Unanswered question 5d703284c8e4820a9b66ddd7 will receive score 0.
# Unanswered question 5d7033dec8e4820a9b66deda will receive score 0.
# Unanswered question 5d70322bc8e4820a9b66ddb3 will receive score 0.
# Unanswered question 5d703296c8e4820a9b66dde1 will receive score 0.
# Unanswered question 5d703591c8e4820a9b66dfa3 will receive score 0.
# Unanswered question 5d70355cc8e4820a9b66df90 will receive score 0.
# Unanswered question 5d70367fc8e4820a9b66e029 will receive score 0.
# Unanswered question 5d70367fc8e4820a9b66e02a will receive score 0.
# Unanswered question 5d703751c8e4820a9b66e09b will receive score 0.
# Unanswered question 5d703682c8e4820a9b66e032 will receive score 0.
# Unanswered question 5d70378ac8e4820a9b66e0ce will receive score 0.
# Unanswered question 5d70362ac8e4820a9b66dffa will receive score 0.
# Unanswered question 5d7036c3c8e4820a9b66e03b will receive score 0.
# Unanswered question 5d703748c8e4820a9b66e088 will receive score 0.
# Unanswered question 5d703748c8e4820a9b66e089 will receive score 0.
# Unanswered question 5d703748c8e4820a9b66e08b will receive score 0.
# Unanswered question 5d70386ac8e4820a9b66e129 will receive score 0.
# Unanswered question 5d703765c8e4820a9b66e0a7 will receive score 0.
# Unanswered question 5d703907c8e4820a9b66e165 will receive score 0.
# Unanswered question 5d703f90c8e4820a9b66e485 will receive score 0.
# Unanswered question 5d703f90c8e4820a9b66e486 will receive score 0.
# Unanswered question 5d703a18c8e4820a9b66e1ee will receive score 0.
# Unanswered question 5d703a24c8e4820a9b66e1fe will receive score 0.
# Unanswered question 5d703a24c8e4820a9b66e200 will receive score 0.
# Unanswered question 5d703c92c8e4820a9b66e342 will receive score 0.
# Unanswered question 5d703d6ac8e4820a9b66e396 will receive score 0.
# Unanswered question 5d703b2bc8e4820a9b66e285 will receive score 0.
# Unanswered question 5d703c64c8e4820a9b66e315 will receive score 0.
# Unanswered question 5d703c68c8e4820a9b66e31f will receive score 0.
# Unanswered question 5d703e8fc8e4820a9b66e40d will receive score 0.
# Unanswered question 5d703c00c8e4820a9b66e2d9 will receive score 0.
# Unanswered question 5d703c00c8e4820a9b66e2da will receive score 0.
# Unanswered question 5d703c00c8e4820a9b66e2db will receive score 0.
# Unanswered question 5d703c44c8e4820a9b66e2f5 will receive score 0.
# Unanswered question 5d703c52c8e4820a9b66e300 will receive score 0.
# Unanswered question 5d703c52c8e4820a9b66e301 will receive score 0.
# Unanswered question 5d703e36c8e4820a9b66e3cd will receive score 0.
# Unanswered question 5d703ee7c8e4820a9b66e436 will receive score 0.
# Unanswered question 5d7040fac8e4820a9b66e53c will receive score 0.
# Unanswered question 5d7040fac8e4820a9b66e53d will receive score 0.
# Unanswered question 5d7040fac8e4820a9b66e53e will receive score 0.
# Unanswered question 5d703f34c8e4820a9b66e457 will receive score 0.
# Unanswered question 5d704006c8e4820a9b66e4a5 will receive score 0.
# Unanswered question 5d7041fdc8e4820a9b66e5f4 will receive score 0.
# Unanswered question 5d7041fdc8e4820a9b66e5f5 will receive score 0.
# Unanswered question 5d704126c8e4820a9b66e57e will receive score 0.
# Unanswered question 5d704355c8e4820a9b66e6a6 will receive score 0.
# Unanswered question 5d704412c8e4820a9b66e73b will receive score 0.
# Unanswered question 5d704242c8e4820a9b66e61f will receive score 0.
# Unanswered question 5d704657c8e4820a9b66e836 will receive score 0.
# Unanswered question 5d7043a6c8e4820a9b66e6f0 will receive score 0.
# Unanswered question 5d7045afc8e4820a9b66e7fc will receive score 0.
# Unanswered question 5d704419c8e4820a9b66e74c will receive score 0.
# Unanswered question 5d7044d3c8e4820a9b66e7af will receive score 0.
# Unanswered question 5d704fbac8e4820a9b66eafd will receive score 0.
# Unanswered question 5d704680c8e4820a9b66e865 will receive score 0.
# Unanswered question 5d704680c8e4820a9b66e866 will receive score 0.
# Unanswered question 5d704a31c8e4820a9b66e966 will receive score 0.
# Unanswered question 5d704b1bc8e4820a9b66e984 will receive score 0.
# Unanswered question 5d704c2ec8e4820a9b66e9db will receive score 0.
# Unanswered question 5d704c2ec8e4820a9b66e9dc will receive score 0.
# Unanswered question 5d704880c8e4820a9b66e8e2 will receive score 0.
# Unanswered question 5d704880c8e4820a9b66e8e3 will receive score 0.
# Unanswered question 5d704b3ac8e4820a9b66e98c will receive score 0.
# Unanswered question 5d704b3ac8e4820a9b66e98d will receive score 0.
# Unanswered question 5d704ed8c8e4820a9b66eaa8 will receive score 0.
# Unanswered question 5d704b80c8e4820a9b66e99f will receive score 0.
# Unanswered question 5d704c45c8e4820a9b66e9ee will receive score 0.
# Unanswered question 5d704e56c8e4820a9b66ea8e will receive score 0.
# Unanswered question 5d704beec8e4820a9b66e9bf will receive score 0.
# Unanswered question 5d704f44c8e4820a9b66ead8 will receive score 0.
# Unanswered question 5d704e74c8e4820a9b66ea9d will receive score 0.
# Unanswered question 5d704e74c8e4820a9b66eaa0 will receive score 0.
# Unanswered question 5d704e3ec8e4820a9b66ea6d will receive score 0.
# Unanswered question 5d705113c8e4820a9b66eb6f will receive score 0.
# Unanswered question 5d705113c8e4820a9b66eb70 will receive score 0.
# Unanswered question 5d704edac8e4820a9b66eab5 will receive score 0.
# Unanswered question 5d7050d0c8e4820a9b66eb5a will receive score 0.
# Unanswered question 5d70509bc8e4820a9b66eb3f will receive score 0.
# Unanswered question 5d7050c0c8e4820a9b66eb49 will receive score 0.
# Unanswered question 5d7050d0c8e4820a9b66eb50 will receive score 0.
# Unanswered question 5d7054ecc8e4820a9b66eca7 will receive score 0.
# Unanswered question 5d7054ecc8e4820a9b66eca8 will receive score 0.
# Unanswered question 5d7054ecc8e4820a9b66eca9 will receive score 0.
# Unanswered question 5d705376c8e4820a9b66ec23 will receive score 0.
# Unanswered question 5d705376c8e4820a9b66ec26 will receive score 0.
# Unanswered question 5d705376c8e4820a9b66ec27 will receive score 0.
# Unanswered question 5d705633c8e4820a9b66ed17 will receive score 0.
# Unanswered question 5d70543ec8e4820a9b66ec5d will receive score 0.
# Unanswered question 5d70550ac8e4820a9b66ecb1 will receive score 0.
# Unanswered question 5d70550bc8e4820a9b66ecbb will receive score 0.
# Unanswered question 5d7053ecc8e4820a9b66ec4d will receive score 0.
# Unanswered question 5d70545bc8e4820a9b66ec65 will receive score 0.
# Unanswered question 5d7054b0c8e4820a9b66ec8c will receive score 0.
# Unanswered question 5d70556cc8e4820a9b66ecc7 will receive score 0.
# Unanswered question 5d7055f1c8e4820a9b66ecf1 will receive score 0.
# Unanswered question 5d705779c8e4820a9b66ed6f will receive score 0.
# Unanswered question 5d70571ec8e4820a9b66ed57 will receive score 0.
# Unanswered question 5d705870c8e4820a9b66edb8 will receive score 0.
# Unanswered question 5d705969c8e4820a9b66ee02 will receive score 0.
# Unanswered question 5d7124b8c8e4820a9b66f764 will receive score 0.
# Unanswered question 5d706064c8e4820a9b66f033 will receive score 0.
# Unanswered question 5d705bd9c8e4820a9b66ef02 will receive score 0.
# Unanswered question 5d705a68c8e4820a9b66ee5f will receive score 0.
# Unanswered question 5d705ca5c8e4820a9b66ef2f will receive score 0.
# Unanswered question 5d705ca5c8e4820a9b66ef30 will receive score 0.
# Unanswered question 5d705ca5c8e4820a9b66ef32 will receive score 0.
# Unanswered question 5d705b05c8e4820a9b66ee8f will receive score 0.
# Unanswered question 5d705b05c8e4820a9b66ee90 will receive score 0.
# Unanswered question 5d705b58c8e4820a9b66eeb3 will receive score 0.
# Unanswered question 5d705b59c8e4820a9b66eebb will receive score 0.
# Unanswered question 5d705b5fc8e4820a9b66eec2 will receive score 0.
# Unanswered question 5d705d54c8e4820a9b66ef69 will receive score 0.
# Unanswered question 5d705dd8c8e4820a9b66efac will receive score 0.
# Unanswered question 5d70858dc8e4820a9b66f437 will receive score 0.
# Unanswered question 5d706579c8e4820a9b66f097 will receive score 0.
# Unanswered question 5d706657c8e4820a9b66f0b3 will receive score 0.
# Unanswered question 5d706657c8e4820a9b66f0b7 will receive score 0.
# Unanswered question 5d706657c8e4820a9b66f0b6 will receive score 0.
# Unanswered question 5d7067bdc8e4820a9b66f0f1 will receive score 0.
# Unanswered question 5d706b28c8e4820a9b66f157 will receive score 0.
# Unanswered question 5d706ed9c8e4820a9b66f1aa will receive score 0.
# Unanswered question 5d706df1c8e4820a9b66f1a0 will receive score 0.
# Unanswered question 5d706df1c8e4820a9b66f1a2 will receive score 0.
# Unanswered question 5d706d5bc8e4820a9b66f18f will receive score 0.
# Unanswered question 5d7078f6c8e4820a9b66f2d9 will receive score 0.
# Unanswered question 5d7078f6c8e4820a9b66f2da will receive score 0.
# Unanswered question 5d7079d7c8e4820a9b66f308 will receive score 0.
# Unanswered question 5d707c9ec8e4820a9b66f354 will receive score 0.
# Unanswered question 5d707c49c8e4820a9b66f349 will receive score 0.
# Unanswered question 5d707d9dc8e4820a9b66f37b will receive score 0.
# Unanswered question 5d707efdc8e4820a9b66f3ac will receive score 0.
# Unanswered question 5d7082d5c8e4820a9b66f405 will receive score 0.
# Unanswered question 5d7082d5c8e4820a9b66f407 will receive score 0.
# Unanswered question 5d708701c8e4820a9b66f454 will receive score 0.
# Unanswered question 5d708701c8e4820a9b66f455 will receive score 0.
# Unanswered question 5d70896fc8e4820a9b66f4aa will receive score 0.
# Unanswered question 5d708b0bc8e4820a9b66f504 will receive score 0.
# Unanswered question 5d70a21dc8e4820a9b66f67c will receive score 0.
# Unanswered question 5d70aa38c8e4820a9b66f6c4 will receive score 0.
# Unanswered question 5d70b163c8e4820a9b66f6ec will receive score 0.
# Unanswered question 5d70b163c8e4820a9b66f6eb will receive score 0.
# Unanswered question 5d70b163c8e4820a9b66f6ed will receive score 0.
# Unanswered question 5d70b163c8e4820a9b66f6ee will receive score 0.
# Unanswered question 5d70b9b2c8e4820a9b66f70b will receive score 0.
# Unanswered question 5d70c3eac8e4820a9b66f713 will receive score 0.
# Unanswered question 5d70c3eac8e4820a9b66f716 will receive score 0.
# Unanswered question 5d70c6cdc8e4820a9b66f71e will receive score 0.
# Unanswered question 5d70c6cdc8e4820a9b66f720 will receive score 0.
# Unanswered question 5d711345c8e4820a9b66f75d will receive score 0.
# Unanswered question 5d706342c8e4820a9b66f05a will receive score 0.
# Unanswered question 5d6fb418c8e4820a9b66a7ae will receive score 0.
# Unanswered question 5d706575c8e4820a9b66f08f will receive score 0.
# Unanswered question 5d70055bc8e4820a9b66a8c3 will receive score 0.
# Unanswered question 5d70068bc8e4820a9b66ab9c will receive score 0.
# Unanswered question 5d700715c8e4820a9b66acd4 will receive score 0.
# Unanswered question 5d7004a9c8e4820a9b66a800 will receive score 0.
# Unanswered question 5d700632c8e4820a9b66aac5 will receive score 0.
# Unanswered question 5d700632c8e4820a9b66aac8 will receive score 0.
# Unanswered question 5d7004f2c8e4820a9b66a82f will receive score 0.
# Unanswered question 5d700598c8e4820a9b66a94c will receive score 0.
# Unanswered question 5d7023f3c8e4820a9b66d03d will receive score 0.
# Unanswered question 5d700525c8e4820a9b66a87e will receive score 0.
# Unanswered question 5d7005e5c8e4820a9b66a9ff will receive score 0.
# Unanswered question 5d7005e4c8e4820a9b66a9ed will receive score 0.
# Unanswered question 5d700762c8e4820a9b66ad6a will receive score 0.
# Unanswered question 5d700563c8e4820a9b66a8d7 will receive score 0.
# Unanswered question 5d7005d7c8e4820a9b66a9c6 will receive score 0.
# Unanswered question 5d700566c8e4820a9b66a8f4 will receive score 0.
# Unanswered question 5d70056ec8e4820a9b66a8fe will receive score 0.
# Unanswered question 5d700670c8e4820a9b66ab60 will receive score 0.
# Unanswered question 5d700670c8e4820a9b66ab61 will receive score 0.
# Unanswered question 5d7005b0c8e4820a9b66a967 will receive score 0.
# Unanswered question 5d700866c8e4820a9b66afe8 will receive score 0.
# Unanswered question 5d700866c8e4820a9b66afe9 will receive score 0.
# Unanswered question 5d70073ec8e4820a9b66ad26 will receive score 0.
# Unanswered question 5d7005dbc8e4820a9b66a9d7 will receive score 0.
# Unanswered question 5d7006f3c8e4820a9b66ac63 will receive score 0.
# Unanswered question 5d7006f3c8e4820a9b66ac64 will receive score 0.
# Unanswered question 5d7005e7c8e4820a9b66aa09 will receive score 0.
# Unanswered question 5d7005e7c8e4820a9b66aa0a will receive score 0.
# Unanswered question 5d70073fc8e4820a9b66ad2d will receive score 0.
# Unanswered question 5d70209fc8e4820a9b66cc8b will receive score 0.
# Unanswered question 5d7021b2c8e4820a9b66cdc2 will receive score 0.
# Unanswered question 5d70243cc8e4820a9b66d06f will receive score 0.
# Unanswered question 5d700635c8e4820a9b66aadd will receive score 0.
# Unanswered question 5d700600c8e4820a9b66aa4e will receive score 0.
# Unanswered question 5d700616c8e4820a9b66aa6c will receive score 0.
# Unanswered question 5d7006efc8e4820a9b66ac52 will receive score 0.
# Unanswered question 5d700632c8e4820a9b66aab5 will receive score 0.
# Unanswered question 5d700634c8e4820a9b66aad2 will receive score 0.
# Unanswered question 5d700659c8e4820a9b66ab1c will receive score 0.
# Unanswered question 5d700673c8e4820a9b66ab69 will receive score 0.
# Unanswered question 5d700673c8e4820a9b66ab6b will receive score 0.
# Unanswered question 5d70081bc8e4820a9b66af4e will receive score 0.
# Unanswered question 5d70081bc8e4820a9b66af4f will receive score 0.
# Unanswered question 5d7009a2c8e4820a9b66b2a2 will receive score 0.
# Unanswered question 5d7006a3c8e4820a9b66abe6 will receive score 0.
# Unanswered question 5d70436ec8e4820a9b66e6bb will receive score 0.
# Unanswered question 5d704777c8e4820a9b66e89a will receive score 0.
# Unanswered question 5d700a0fc8e4820a9b66b377 will receive score 0.
# Unanswered question 5d700820c8e4820a9b66af5a will receive score 0.
# Unanswered question 5d700715c8e4820a9b66acce will receive score 0.
# Unanswered question 5d7007b4c8e4820a9b66ae6e will receive score 0.
# Unanswered question 5d700853c8e4820a9b66afd4 will receive score 0.
# Unanswered question 5d700853c8e4820a9b66afd5 will receive score 0.
# Unanswered question 5d700a33c8e4820a9b66b3c0 will receive score 0.
# Unanswered question 5d7008f2c8e4820a9b66b125 will receive score 0.
# Unanswered question 5d700730c8e4820a9b66ad13 will receive score 0.
# Unanswered question 5d700920c8e4820a9b66b199 will receive score 0.
# Unanswered question 5d7009fac8e4820a9b66b32f will receive score 0.
# Unanswered question 5d7009fac8e4820a9b66b331 will receive score 0.
# Unanswered question 5d700748c8e4820a9b66ad38 will receive score 0.
# Unanswered question 5d7011b6c8e4820a9b66be33 will receive score 0.
# Unanswered question 5d700759c8e4820a9b66ad4e will receive score 0.
# Unanswered question 5d700759c8e4820a9b66ad4c will receive score 0.
# Unanswered question 5d701495c8e4820a9b66c0ad will receive score 0.
# Unanswered question 5d701495c8e4820a9b66c0af will receive score 0.
# Unanswered question 5d700766c8e4820a9b66ad7c will receive score 0.
# Unanswered question 5d7007e2c8e4820a9b66aed1 will receive score 0.
# Unanswered question 5d7007e2c8e4820a9b66aed2 will receive score 0.
# Unanswered question 5d7007e2c8e4820a9b66aed3 will receive score 0.
# Unanswered question 5d70087dc8e4820a9b66b00b will receive score 0.
# Unanswered question 5d700796c8e4820a9b66ae1f will receive score 0.
# Unanswered question 5d700796c8e4820a9b66ae21 will receive score 0.
# Unanswered question 5d700cebc8e4820a9b66b852 will receive score 0.
# Unanswered question 5d70109ec8e4820a9b66bd0a will receive score 0.
# Unanswered question 5d7008fcc8e4820a9b66b141 will receive score 0.
# Unanswered question 5d700a4ec8e4820a9b66b3fc will receive score 0.
# Unanswered question 5d7007a0c8e4820a9b66ae46 will receive score 0.
# Unanswered question 5d7007a0c8e4820a9b66ae49 will receive score 0.
# Unanswered question 5d70089ec8e4820a9b66b05f will receive score 0.
# Unanswered question 5d70089ec8e4820a9b66b063 will receive score 0.
# Unanswered question 5d7008b2c8e4820a9b66b090 will receive score 0.
# Unanswered question 5d7007bac8e4820a9b66ae7a will receive score 0.
# Unanswered question 5d7007ebc8e4820a9b66aee2 will receive score 0.
# Unanswered question 5d7007ebc8e4820a9b66aee5 will receive score 0.
# Unanswered question 5d70284dc8e4820a9b66d5f7 will receive score 0.
# Unanswered question 5d702c19c8e4820a9b66d997 will receive score 0.
# Unanswered question 5d7007ecc8e4820a9b66aeef will receive score 0.
# Unanswered question 5d700ab3c8e4820a9b66b4c6 will receive score 0.
# Unanswered question 5d700c65c8e4820a9b66b77f will receive score 0.
# Unanswered question 5d700c65c8e4820a9b66b783 will receive score 0.
# Unanswered question 5d7008adc8e4820a9b66b087 will receive score 0.
# Unanswered question 5d7008adc8e4820a9b66b088 will receive score 0.
# Unanswered question 5d7008adc8e4820a9b66b089 will receive score 0.
# Unanswered question 5d700950c8e4820a9b66b1bf will receive score 0.
# Unanswered question 5d700826c8e4820a9b66af62 will receive score 0.
# Unanswered question 5d700842c8e4820a9b66afbb will receive score 0.
# Unanswered question 5d7009adc8e4820a9b66b2aa will receive score 0.
# Unanswered question 5d700a2ec8e4820a9b66b3b3 will receive score 0.
# Unanswered question 5d700a2ec8e4820a9b66b3b6 will receive score 0.
# Unanswered question 5d700caac8e4820a9b66b804 will receive score 0.
# Unanswered question 5d700caac8e4820a9b66b806 will receive score 0.
# Unanswered question 5d7008bfc8e4820a9b66b0af will receive score 0.
# Unanswered question 5d7008c5c8e4820a9b66b0d6 will receive score 0.
# Unanswered question 5d7008e6c8e4820a9b66b10e will receive score 0.
# Unanswered question 5d700903c8e4820a9b66b149 will receive score 0.
# Unanswered question 5d700a18c8e4820a9b66b393 will receive score 0.
# Unanswered question 5d700913c8e4820a9b66b17c will receive score 0.
# Unanswered question 5d700913c8e4820a9b66b17e will receive score 0.
# Unanswered question 5d700968c8e4820a9b66b20d will receive score 0.
# Unanswered question 5d700968c8e4820a9b66b20f will receive score 0.
# Unanswered question 5d700968c8e4820a9b66b210 will receive score 0.
# Unanswered question 5d70097ac8e4820a9b66b225 will receive score 0.
# Unanswered question 5d700d41c8e4820a9b66b8be will receive score 0.
# Unanswered question 5d700b4ac8e4820a9b66b5f1 will receive score 0.
# Unanswered question 5d700cc7c8e4820a9b66b821 will receive score 0.
# Unanswered question 5d700a4ac8e4820a9b66b3f1 will receive score 0.
# Unanswered question 5d700bb3c8e4820a9b66b693 will receive score 0.
# Unanswered question 5d700a54c8e4820a9b66b40d will receive score 0.
# Unanswered question 5d700c5ac8e4820a9b66b75a will receive score 0.
# Unanswered question 5d700a69c8e4820a9b66b419 will receive score 0.
# Unanswered question 5d700a93c8e4820a9b66b491 will receive score 0.
# Unanswered question 5d700b05c8e4820a9b66b549 will receive score 0.
# Unanswered question 5d700b0ec8e4820a9b66b557 will receive score 0.
# Unanswered question 5d700b0ec8e4820a9b66b55b will receive score 0.
# Unanswered question 5d700b4ac8e4820a9b66b5fc will receive score 0.
# Unanswered question 5d700b4fc8e4820a9b66b609 will receive score 0.
# Unanswered question 5d700f6bc8e4820a9b66bb7b will receive score 0.
# Unanswered question 5d700f6bc8e4820a9b66bb7d will receive score 0.
# Unanswered question 5d700f6bc8e4820a9b66bb7e will receive score 0.
# Unanswered question 5d701018c8e4820a9b66bc30 will receive score 0.
# Unanswered question 5d700d81c8e4820a9b66b924 will receive score 0.
# Unanswered question 5d700c8ac8e4820a9b66b7dd will receive score 0.
# Unanswered question 5d700c6bc8e4820a9b66b7a3 will receive score 0.
# Unanswered question 5d700dccc8e4820a9b66b975 will receive score 0.
# Unanswered question 5d704395c8e4820a9b66e6e0 will receive score 0.
# Unanswered question 5d701545c8e4820a9b66c150 will receive score 0.
# Unanswered question 5d700cfcc8e4820a9b66b88c will receive score 0.
# Unanswered question 5d700fe1c8e4820a9b66bbe6 will receive score 0.
# Unanswered question 5d700d20c8e4820a9b66b8b1 will receive score 0.
# Unanswered question 5d700d20c8e4820a9b66b8b5 will receive score 0.
# Unanswered question 5d70109fc8e4820a9b66bd13 will receive score 0.
# Unanswered question 5d701190c8e4820a9b66be05 will receive score 0.
# Unanswered question 5d701190c8e4820a9b66be04 will receive score 0.
# Unanswered question 5d701190c8e4820a9b66be06 will receive score 0.
# Unanswered question 5d701005c8e4820a9b66bc12 will receive score 0.
# Unanswered question 5d701174c8e4820a9b66bdf5 will receive score 0.
# Unanswered question 5d700d73c8e4820a9b66b90b will receive score 0.
# Unanswered question 5d700d7cc8e4820a9b66b91c will receive score 0.
# Unanswered question 5d700db7c8e4820a9b66b959 will receive score 0.
# Unanswered question 5d702159c8e4820a9b66cd40 will receive score 0.
# Unanswered question 5d701195c8e4820a9b66be10 will receive score 0.
# Unanswered question 5d701195c8e4820a9b66be11 will receive score 0.
# Unanswered question 5d700e1ac8e4820a9b66b9e5 will receive score 0.
# Unanswered question 5d700fcac8e4820a9b66bbda will receive score 0.
# Unanswered question 5d700fcac8e4820a9b66bbdb will receive score 0.
# Unanswered question 5d700ed8c8e4820a9b66bae3 will receive score 0.
# Unanswered question 5d700ed8c8e4820a9b66bae2 will receive score 0.
# Unanswered question 5d70107cc8e4820a9b66bce5 will receive score 0.
# Unanswered question 5d700ec7c8e4820a9b66babd will receive score 0.
# Unanswered question 5d700f41c8e4820a9b66bb3f will receive score 0.
# ...
# Unanswered question 5d7028afc8e4820a9b66d64b will receive score 0.
# Unanswered question 5d702588c8e4820a9b66d1df will receive score 0.
# Unanswered question 5d702435c8e4820a9b66d066 will receive score 0.
# Unanswered question 5d7025ecc8e4820a9b66d229 will receive score 0.
# Unanswered question 5d7023dec8e4820a9b66d023 will receive score 0.
# Unanswered question 5d70242bc8e4820a9b66d05d will receive score 0.
# Unanswered question 5d702440c8e4820a9b66d077 will receive score 0.
# Unanswered question 5d70290fc8e4820a9b66d6e1 will receive score 0.
# Unanswered question 5d702a09c8e4820a9b66d781 will receive score 0.
# Unanswered question 5d702a09c8e4820a9b66d783 will receive score 0.
# Unanswered question 5d702a09c8e4820a9b66d784 will receive score 0.
# Unanswered question 5d702669c8e4820a9b66d2a7 will receive score 0.
# Unanswered question 5d702669c8e4820a9b66d2a8 will receive score 0.
# Unanswered question 5d702498c8e4820a9b66d0c5 will receive score 0.
# Unanswered question 5d7024f2c8e4820a9b66d176 will receive score 0.
# Unanswered question 5d7024ffc8e4820a9b66d189 will receive score 0.
# Unanswered question 5d7025d0c8e4820a9b66d207 will receive score 0.
# Unanswered question 5d7025d0c8e4820a9b66d209 will receive score 0.
# Unanswered question 5d7025d0c8e4820a9b66d208 will receive score 0.
# Unanswered question 5d7027a5c8e4820a9b66d56e will receive score 0.
# Unanswered question 5d7027a5c8e4820a9b66d570 will receive score 0.
# Unanswered question 5d702653c8e4820a9b66d289 will receive score 0.
# Unanswered question 5d7028bac8e4820a9b66d673 will receive score 0.
# Unanswered question 5d702785c8e4820a9b66d553 will receive score 0.
# Unanswered question 5d702732c8e4820a9b66d4f9 will receive score 0.
# Unanswered question 5d7028ccc8e4820a9b66d67d will receive score 0.
# Unanswered question 5d7028ccc8e4820a9b66d67e will receive score 0.
# Unanswered question 5d7028ccc8e4820a9b66d680 will receive score 0.
# Unanswered question 5d7028ccc8e4820a9b66d681 will receive score 0.
# Unanswered question 5d7026c8c8e4820a9b66d337 will receive score 0.
# Unanswered question 5d7026d1c8e4820a9b66d349 will receive score 0.
# Unanswered question 5d7026d1c8e4820a9b66d34a will receive score 0.
# Unanswered question 5d7026d7c8e4820a9b66d352 will receive score 0.
# Unanswered question 5d7026dac8e4820a9b66d35c will receive score 0.
# Unanswered question 5d7026dbc8e4820a9b66d370 will receive score 0.
# Unanswered question 5d7026dfc8e4820a9b66d37a will receive score 0.
# Unanswered question 5d7026e0c8e4820a9b66d384 will receive score 0.
# Unanswered question 5d7026e0c8e4820a9b66d38e will receive score 0.
# Unanswered question 5d7026e0c8e4820a9b66d393 will receive score 0.
# Unanswered question 5d70280ac8e4820a9b66d5b5 will receive score 0.
# Unanswered question 5d702725c8e4820a9b66d4ef will receive score 0.
# Unanswered question 5d702725c8e4820a9b66d4f1 will receive score 0.
# Unanswered question 5d702784c8e4820a9b66d54c will receive score 0.
# Unanswered question 5d702919c8e4820a9b66d6ea will receive score 0.
# Unanswered question 5d7028a9c8e4820a9b66d641 will receive score 0.
# Unanswered question 5d7028b2c8e4820a9b66d65f will receive score 0.
# Unanswered question 5d7029bbc8e4820a9b66d767 will receive score 0.
# Unanswered question 5d70290cc8e4820a9b66d6d9 will receive score 0.
# Unanswered question 5d7029b4c8e4820a9b66d761 will receive score 0.
# Unanswered question 5d702c0ac8e4820a9b66d984 will receive score 0.
# Unanswered question 5d702d0fc8e4820a9b66da92 will receive score 0.
# Unanswered question 5d702d0fc8e4820a9b66da93 will receive score 0.
# Unanswered question 5d702a95c8e4820a9b66d82f will receive score 0.
# Unanswered question 5d702b18c8e4820a9b66d890 will receive score 0.
# Unanswered question 5d702acec8e4820a9b66d854 will receive score 0.
# Unanswered question 5d702acec8e4820a9b66d855 will receive score 0.
# Unanswered question 5d702b75c8e4820a9b66d905 will receive score 0.
# Unanswered question 5d702c21c8e4820a9b66d99d will receive score 0.
# Unanswered question 5d702c21c8e4820a9b66d9a0 will receive score 0.
# Unanswered question 5d702cf2c8e4820a9b66da7d will receive score 0.
# Unanswered question 5d702cf2c8e4820a9b66da7f will receive score 0.
# Unanswered question 5d702d18c8e4820a9b66daa7 will receive score 0.
# Unanswered question 5d702cd9c8e4820a9b66da59 will receive score 0.
# Unanswered question 5d702dd6c8e4820a9b66db35 will receive score 0.
# Unanswered question 5d702dd6c8e4820a9b66db37 will receive score 0.
# Unanswered question 5d702ed1c8e4820a9b66dc02 will receive score 0.
# Unanswered question 5d702e78c8e4820a9b66dbbd will receive score 0.
# Unanswered question 5d703188c8e4820a9b66dd53 will receive score 0.
# Unanswered question 5d703188c8e4820a9b66dd56 will receive score 0.
# Unanswered question 5d702ed3c8e4820a9b66dc0b will receive score 0.
# Unanswered question 5d703091c8e4820a9b66dcc3 will receive score 0.
# Unanswered question 5d702ee3c8e4820a9b66dc17 will receive score 0.
# Unanswered question 5d702f4fc8e4820a9b66dc29 will receive score 0.
# Unanswered question 5d7030a4c8e4820a9b66dcd4 will receive score 0.
# Unanswered question 5d7030a4c8e4820a9b66dcd5 will receive score 0.
# Unanswered question 5d7030a4c8e4820a9b66dcd7 will receive score 0.
# Unanswered question 5d702ff0c8e4820a9b66dc89 will receive score 0.
# Unanswered question 5d70315fc8e4820a9b66dd38 will receive score 0.
# Unanswered question 5d7031ddc8e4820a9b66dd84 will receive score 0.
# Unanswered question 5d703059c8e4820a9b66dca3 will receive score 0.
# Unanswered question 5d7031ffc8e4820a9b66dd9c will receive score 0.
# Unanswered question 5d7032b7c8e4820a9b66ddf4 will receive score 0.
# Unanswered question 5d703555c8e4820a9b66df72 will receive score 0.
# Unanswered question 5d703f54c8e4820a9b66e469 will receive score 0.
# Unanswered question 5d7031cbc8e4820a9b66dd71 will receive score 0.
# Unanswered question 5d70344dc8e4820a9b66deee will receive score 0.
# Unanswered question 5d703209c8e4820a9b66dda9 will receive score 0.
# Unanswered question 5d703284c8e4820a9b66ddd5 will receive score 0.
# Unanswered question 5d703284c8e4820a9b66ddd7 will receive score 0.
# Unanswered question 5d7033dec8e4820a9b66deda will receive score 0.
# Unanswered question 5d70322bc8e4820a9b66ddb3 will receive score 0.
# Unanswered question 5d703296c8e4820a9b66dde1 will receive score 0.
# Unanswered question 5d703591c8e4820a9b66dfa3 will receive score 0.
# Unanswered question 5d70355cc8e4820a9b66df90 will receive score 0.
# Unanswered question 5d70367fc8e4820a9b66e029 will receive score 0.
# Unanswered question 5d70367fc8e4820a9b66e02a will receive score 0.
# Unanswered question 5d703751c8e4820a9b66e09b will receive score 0.
# Unanswered question 5d703682c8e4820a9b66e032 will receive score 0.
# Unanswered question 5d70378ac8e4820a9b66e0ce will receive score 0.
# Unanswered question 5d70362ac8e4820a9b66dffa will receive score 0.
# Unanswered question 5d7036c3c8e4820a9b66e03b will receive score 0.
# Unanswered question 5d703748c8e4820a9b66e088 will receive score 0.
# Unanswered question 5d703748c8e4820a9b66e089 will receive score 0.
# Unanswered question 5d703748c8e4820a9b66e08b will receive score 0.
# Unanswered question 5d70386ac8e4820a9b66e129 will receive score 0.
# Unanswered question 5d703765c8e4820a9b66e0a7 will receive score 0.
# Unanswered question 5d703907c8e4820a9b66e165 will receive score 0.
# Unanswered question 5d703f90c8e4820a9b66e485 will receive score 0.
# Unanswered question 5d703f90c8e4820a9b66e486 will receive score 0.
# Unanswered question 5d703a18c8e4820a9b66e1ee will receive score 0.
# Unanswered question 5d703a24c8e4820a9b66e1fe will receive score 0.
# Unanswered question 5d703a24c8e4820a9b66e200 will receive score 0.
# Unanswered question 5d703c92c8e4820a9b66e342 will receive score 0.
# Unanswered question 5d703d6ac8e4820a9b66e396 will receive score 0.
# Unanswered question 5d703b2bc8e4820a9b66e285 will receive score 0.
# Unanswered question 5d703c64c8e4820a9b66e315 will receive score 0.
# Unanswered question 5d703c68c8e4820a9b66e31f will receive score 0.
# Unanswered question 5d703e8fc8e4820a9b66e40d will receive score 0.
# Unanswered question 5d703c00c8e4820a9b66e2d9 will receive score 0.
# Unanswered question 5d703c00c8e4820a9b66e2da will receive score 0.
# Unanswered question 5d703c00c8e4820a9b66e2db will receive score 0.
# Unanswered question 5d703c44c8e4820a9b66e2f5 will receive score 0.
# Unanswered question 5d703c52c8e4820a9b66e300 will receive score 0.
# Unanswered question 5d703c52c8e4820a9b66e301 will receive score 0.
# Unanswered question 5d703e36c8e4820a9b66e3cd will receive score 0.
# Unanswered question 5d703ee7c8e4820a9b66e436 will receive score 0.
# Unanswered question 5d7040fac8e4820a9b66e53c will receive score 0.
# Unanswered question 5d7040fac8e4820a9b66e53d will receive score 0.
# Unanswered question 5d7040fac8e4820a9b66e53e will receive score 0.
# Unanswered question 5d703f34c8e4820a9b66e457 will receive score 0.
# Unanswered question 5d704006c8e4820a9b66e4a5 will receive score 0.
# Unanswered question 5d7041fdc8e4820a9b66e5f4 will receive score 0.
# Unanswered question 5d7041fdc8e4820a9b66e5f5 will receive score 0.
# Unanswered question 5d704126c8e4820a9b66e57e will receive score 0.
# Unanswered question 5d704355c8e4820a9b66e6a6 will receive score 0.
# Unanswered question 5d704412c8e4820a9b66e73b will receive score 0.
# Unanswered question 5d704242c8e4820a9b66e61f will receive score 0.
# Unanswered question 5d704657c8e4820a9b66e836 will receive score 0.
# Unanswered question 5d7043a6c8e4820a9b66e6f0 will receive score 0.
# Unanswered question 5d7045afc8e4820a9b66e7fc will receive score 0.
# Unanswered question 5d704419c8e4820a9b66e74c will receive score 0.
# Unanswered question 5d7044d3c8e4820a9b66e7af will receive score 0.
# Unanswered question 5d704fbac8e4820a9b66eafd will receive score 0.
# Unanswered question 5d704680c8e4820a9b66e865 will receive score 0.
# Unanswered question 5d704680c8e4820a9b66e866 will receive score 0.
# Unanswered question 5d704a31c8e4820a9b66e966 will receive score 0.
# Unanswered question 5d704b1bc8e4820a9b66e984 will receive score 0.
# Unanswered question 5d704c2ec8e4820a9b66e9db will receive score 0.
# Unanswered question 5d704c2ec8e4820a9b66e9dc will receive score 0.
# Unanswered question 5d704880c8e4820a9b66e8e2 will receive score 0.
# Unanswered question 5d704880c8e4820a9b66e8e3 will receive score 0.
# Unanswered question 5d704b3ac8e4820a9b66e98c will receive score 0.
# Unanswered question 5d704b3ac8e4820a9b66e98d will receive score 0.
# Unanswered question 5d704ed8c8e4820a9b66eaa8 will receive score 0.
# Unanswered question 5d704b80c8e4820a9b66e99f will receive score 0.
# Unanswered question 5d704c45c8e4820a9b66e9ee will receive score 0.
# Unanswered question 5d704e56c8e4820a9b66ea8e will receive score 0.
# Unanswered question 5d704beec8e4820a9b66e9bf will receive score 0.
# Unanswered question 5d704f44c8e4820a9b66ead8 will receive score 0.
# Unanswered question 5d704e74c8e4820a9b66ea9d will receive score 0.
# Unanswered question 5d704e74c8e4820a9b66eaa0 will receive score 0.
# Unanswered question 5d704e3ec8e4820a9b66ea6d will receive score 0.
# Unanswered question 5d705113c8e4820a9b66eb6f will receive score 0.
# Unanswered question 5d705113c8e4820a9b66eb70 will receive score 0.
# Unanswered question 5d704edac8e4820a9b66eab5 will receive score 0.
# Unanswered question 5d7050d0c8e4820a9b66eb5a will receive score 0.
# Unanswered question 5d70509bc8e4820a9b66eb3f will receive score 0.
# Unanswered question 5d7050c0c8e4820a9b66eb49 will receive score 0.
# Unanswered question 5d7050d0c8e4820a9b66eb50 will receive score 0.
# Unanswered question 5d7054ecc8e4820a9b66eca7 will receive score 0.
# Unanswered question 5d7054ecc8e4820a9b66eca8 will receive score 0.
# Unanswered question 5d7054ecc8e4820a9b66eca9 will receive score 0.
# Unanswered question 5d705376c8e4820a9b66ec23 will receive score 0.
# Unanswered question 5d705376c8e4820a9b66ec26 will receive score 0.
# Unanswered question 5d705376c8e4820a9b66ec27 will receive score 0.
# Unanswered question 5d705633c8e4820a9b66ed17 will receive score 0.
# Unanswered question 5d70543ec8e4820a9b66ec5d will receive score 0.
# Unanswered question 5d70550ac8e4820a9b66ecb1 will receive score 0.
# Unanswered question 5d70550bc8e4820a9b66ecbb will receive score 0.
# Unanswered question 5d7053ecc8e4820a9b66ec4d will receive score 0.
# Unanswered question 5d70545bc8e4820a9b66ec65 will receive score 0.
# Unanswered question 5d7054b0c8e4820a9b66ec8c will receive score 0.
# Unanswered question 5d70556cc8e4820a9b66ecc7 will receive score 0.
# Unanswered question 5d7055f1c8e4820a9b66ecf1 will receive score 0.
# Unanswered question 5d705779c8e4820a9b66ed6f will receive score 0.
# Unanswered question 5d70571ec8e4820a9b66ed57 will receive score 0.
# Unanswered question 5d705870c8e4820a9b66edb8 will receive score 0.
# Unanswered question 5d705969c8e4820a9b66ee02 will receive score 0.
# Unanswered question 5d7124b8c8e4820a9b66f764 will receive score 0.
# Unanswered question 5d706064c8e4820a9b66f033 will receive score 0.
# Unanswered question 5d705bd9c8e4820a9b66ef02 will receive score 0.
# Unanswered question 5d705a68c8e4820a9b66ee5f will receive score 0.
# Unanswered question 5d705ca5c8e4820a9b66ef2f will receive score 0.
# Unanswered question 5d705ca5c8e4820a9b66ef30 will receive score 0.
# Unanswered question 5d705ca5c8e4820a9b66ef32 will receive score 0.
# Unanswered question 5d705b05c8e4820a9b66ee8f will receive score 0.
# Unanswered question 5d705b05c8e4820a9b66ee90 will receive score 0.
# Unanswered question 5d705b58c8e4820a9b66eeb3 will receive score 0.
# Unanswered question 5d705b59c8e4820a9b66eebb will receive score 0.
# Unanswered question 5d705b5fc8e4820a9b66eec2 will receive score 0.
# Unanswered question 5d705d54c8e4820a9b66ef69 will receive score 0.
# Unanswered question 5d705dd8c8e4820a9b66efac will receive score 0.
# Unanswered question 5d70858dc8e4820a9b66f437 will receive score 0.
# Unanswered question 5d706579c8e4820a9b66f097 will receive score 0.
# Unanswered question 5d706657c8e4820a9b66f0b3 will receive score 0.
# Unanswered question 5d706657c8e4820a9b66f0b7 will receive score 0.
# Unanswered question 5d706657c8e4820a9b66f0b6 will receive score 0.
# Unanswered question 5d7067bdc8e4820a9b66f0f1 will receive score 0.
# Unanswered question 5d706b28c8e4820a9b66f157 will receive score 0.
# Unanswered question 5d706ed9c8e4820a9b66f1aa will receive score 0.
# Unanswered question 5d706df1c8e4820a9b66f1a0 will receive score 0.
# Unanswered question 5d706df1c8e4820a9b66f1a2 will receive score 0.
# Unanswered question 5d706d5bc8e4820a9b66f18f will receive score 0.
# Unanswered question 5d7078f6c8e4820a9b66f2d9 will receive score 0.
# Unanswered question 5d7078f6c8e4820a9b66f2da will receive score 0.
# Unanswered question 5d7079d7c8e4820a9b66f308 will receive score 0.
# Unanswered question 5d707c9ec8e4820a9b66f354 will receive score 0.
# Unanswered question 5d707c49c8e4820a9b66f349 will receive score 0.
# Unanswered question 5d707d9dc8e4820a9b66f37b will receive score 0.
# Unanswered question 5d707efdc8e4820a9b66f3ac will receive score 0.
# Unanswered question 5d7082d5c8e4820a9b66f405 will receive score 0.
# Unanswered question 5d7082d5c8e4820a9b66f407 will receive score 0.
# Unanswered question 5d708701c8e4820a9b66f454 will receive score 0.
# Unanswered question 5d708701c8e4820a9b66f455 will receive score 0.
# Unanswered question 5d70896fc8e4820a9b66f4aa will receive score 0.
# Unanswered question 5d708b0bc8e4820a9b66f504 will receive score 0.
# Unanswered question 5d70a21dc8e4820a9b66f67c will receive score 0.
# Unanswered question 5d70aa38c8e4820a9b66f6c4 will receive score 0.
# Unanswered question 5d70b163c8e4820a9b66f6ec will receive score 0.
# Unanswered question 5d70b163c8e4820a9b66f6eb will receive score 0.
# Unanswered question 5d70b163c8e4820a9b66f6ed will receive score 0.
# Unanswered question 5d70b163c8e4820a9b66f6ee will receive score 0.
# Unanswered question 5d70b9b2c8e4820a9b66f70b will receive score 0.
# Unanswered question 5d70c3eac8e4820a9b66f713 will receive score 0.
# Unanswered question 5d70c3eac8e4820a9b66f716 will receive score 0.
# Unanswered question 5d70c6cdc8e4820a9b66f71e will receive score 0.
# Unanswered question 5d70c6cdc8e4820a9b66f720 will receive score 0.
# Unanswered question 5d711345c8e4820a9b66f75d will receive score 0.

# %% [markdown]
# ### Write model results to CSV and parquet

# %%
def write_results_csv(model_results):
    filename = '/data/distribution_shift/augmented_qa/results/model_results.csv'
    
    print("Writting: {}".format(filename))
    with open(filename, 'w', encoding='utf-8') as f:
        csv_writer = csv.writer(f, dialect='excel')
        csv_writer.writerows(model_results)
        
    return filename

write_results_csv(model_results)
# Out:
# Writting: /data/distribution_shift/augmented_qa/results/model_results.csv
# '/data/distribution_shift/augmented_qa/results/model_results.csv'

# %%
filename = '/data/distribution_shift/augmented_qa/results/model_results.parquet.gzip'

model_results_df = pd.DataFrame(model_results[1:], columns=model_results[0])

model_results_df['question_set'] = model_results_df['question_set'].astype('category')
model_results_df['questions'] = model_results_df['questions'].astype('category')
model_results_df['predictions'] = model_results_df['predictions'].astype('category')
model_results_df['augmentation_model'] = model_results_df['augmentation_model'].astype('category')
model_results_df['question_answering_model'] = model_results_df['question_answering_model'].astype('category')
model_results_df['augmentation_name'] = model_results_df['augmentation_name'].astype('category')

print("Writting: {}".format(filename))
model_results_df.to_parquet(filename,
              compression='gzip') 

model_results_df.head()
# Out:
# Writting: /data/distribution_shift/augmented_qa/results/model_results.parquet.gzip
#           question_set            questions  \
# 0  amazon_reviews_v1_0  amazon_reviews_v1.0
# 1  amazon_reviews_v1_0  amazon_reviews_v1.0
# 2  amazon_reviews_v1_0  amazon_reviews_v1.0
# 3  amazon_reviews_v1_0  amazon_reviews_v1.0
# 4          reddit_v1_0          reddit_v1.0
#
#                                          predictions augmentation_model  \
# 0  amazon_reviews_v1_0_bert-large-cased-whole-wor...               orig
# 1  amazon_reviews_v1_0_bert-large-uncased-whole-w...               orig
# 2  amazon_reviews_v1_0_distilbert-base-cased-dist...               orig
# 3  amazon_reviews_v1_0_distilbert-base-uncased-di...               orig
# 4  reddit_v1_0_bert-large-cased-whole-word-maskin...               orig
#
#   parts_of_speech  frequency_percentile augmentation_name  \
# 0            None                   NaN          Original
# 1            None                   NaN          Original
# 2            None                   NaN          Original
# 3            None                   NaN          Original
# 4            None                   NaN          Original
#
#                             question_answering_model  exact_match         f1
# 0  bert-large-cased-whole-word-masking-finetuned-...    61.294891  76.448281
# 1  bert-large-uncased-whole-word-masking-finetune...    61.446636  77.010119
# 2              distilbert-base-cased-distilled-squad    52.149722  67.433575
# 3            distilbert-base-uncased-distilled-squad    51.785534  67.140229
# 4  bert-large-cased-whole-word-masking-finetuned-...    61.215954  75.005330

# %% [markdown]
# ### Write model question results to CSV and parquet

# %%
def write_question_results_csv(question_results):
    filename = '/data/distribution_shift/augmented_qa/results/question_results.csv'
    
    print("Writting: {}".format(filename))
    with open(filename, 'w', encoding='utf-8') as f:
        csv_writer = csv.writer(f, dialect='excel')
        csv_writer.writerows(question_results)
        
    return filename

write_question_results_csv(model_question_results)
# Out:
# Writting: /data/distribution_shift/augmented_qa/results/question_results.csv
# '/data/distribution_shift/augmented_qa/results/question_results.csv'

# %%
filename = '/data/distribution_shift/augmented_qa/results/question_results.parquet.gzip'

model_question_results_df = pd.DataFrame(model_question_results[1:],
                                        columns=model_question_results[0]
                                        )

model_question_results_df['question_set'] = model_question_results_df['question_set'].astype('category')
model_question_results_df['questions'] = model_question_results_df['questions'].astype('category')
model_question_results_df['predictions'] = model_question_results_df['predictions'].astype('category')
model_question_results_df['augmentation_model'] = model_question_results_df['augmentation_model'].astype('category')
model_question_results_df['augmentation_name'] = model_question_results_df['augmentation_name'].astype('category')
model_question_results_df['question_answering_model'] = model_question_results_df['question_answering_model'].astype('category')


print("Writting: {}".format(filename))
model_question_results_df.to_parquet(filename,
              compression='gzip') 

model_question_results_df.head()
# Out:
# Writting: /data/distribution_shift/augmented_qa/results/question_results.parquet.gzip
#           question_set            questions  \
# 0  amazon_reviews_v1_0  amazon_reviews_v1.0
# 1  amazon_reviews_v1_0  amazon_reviews_v1.0
# 2  amazon_reviews_v1_0  amazon_reviews_v1.0
# 3  amazon_reviews_v1_0  amazon_reviews_v1.0
# 4  amazon_reviews_v1_0  amazon_reviews_v1.0
#
#                                          predictions augmentation_model  \
# 0  amazon_reviews_v1_0_bert-large-cased-whole-wor...               orig
# 1  amazon_reviews_v1_0_bert-large-cased-whole-wor...               orig
# 2  amazon_reviews_v1_0_bert-large-cased-whole-wor...               orig
# 3  amazon_reviews_v1_0_bert-large-cased-whole-wor...               orig
# 4  amazon_reviews_v1_0_bert-large-cased-whole-wor...               orig
#
#   augmentation_name                           question_answering_model  \
# 0          Original  bert-large-cased-whole-word-masking-finetuned-...
# 1          Original  bert-large-cased-whole-word-masking-finetuned-...
# 2          Original  bert-large-cased-whole-word-masking-finetuned-...
# 3          Original  bert-large-cased-whole-word-masking-finetuned-...
# 4          Original  bert-large-cased-whole-word-masking-finetuned-...
#
#                 question_id  exact_match        f1
# 0  5dd465dacc027a086d65bc6c         True  1.000000
# 1  5dd465dacc027a086d65bc6d        False  0.888889
# 2  5dd465dacc027a086d65bc6e         True  1.000000
# 3  5dd465dacc027a086d65bc6f        False  0.571429
# 4  5dd465dacc027a086d65bc70        False  0.000000
